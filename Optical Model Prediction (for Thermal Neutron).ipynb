# %% [markdown]
# <a href="https://colab.research.google.com/github/dehpour/Neutron-Cross-Section/blob/main/Optical%20Model%20Prediction%20(for%20Thermal%20Neutron).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A ,order = 235, 100

# %%
E = np.arange(0.001, 0.1, 0.0001)                                           #ev
k2 = []                                                                     #fm^-2
for i in range (len(E)):
  k2.append((2*939.57*E[i]*10**-6)/(197.33**2))
k = np.sqrt(k2)                                                             #fm^-1
a = 1.35*A**(1/3)                                                           #fm

# %%
sigma = []
sum = []
for j in range (len(E)):
  for l in range (order):
    sum.append((4*np.pi/k2[j])*( (2*l+1)*(np.sin(k[j]*a)**(2*l+1))**2)/100) #divide by 100 for convert fm^2 to barn
  sigma.append(np.sum(sum))
  sum = []

plt.figure(figsize=(10, 5),dpi=100)
plt.yscale("log")
plt.title('Thermal Neutron Scattering Cross-Section from A = '+str(A))
plt.xlabel('Neutron Energy [eV]')
plt.ylabel('X. S. [barn]')
plt.plot(E, sigma)
plt.show()
